# %% [markdown]
# # Making plots with plotnine
# Here's where we finally make some pretty graphs

# %%
import plotnine as p9

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('https://ndownloader.figshare.com/files/10717177')
surveys_df.sample(4)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 26738      26739      7   30  1997        8         PP    M             20.0
# 22110      22111      3    4  1995        7         AB  NaN              NaN
# 26423      26424      7    9  1997       16         PL    F             22.0
# 3159        3160      7   22  1980        1         SS  NaN              NaN
#
#        weight
# 26738    11.0
# 22110     NaN
# 26423    18.0
# 3159      NaN

# %%
surveys_complete = surveys_df.dropna()
surveys_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30676 entries, 62 to 35547
# Data columns (total 9 columns):
# record_id          30676 non-null int64
# month              30676 non-null int64
# day                30676 non-null int64
# year               30676 non-null int64
# plot_id            30676 non-null int64
# species_id         30676 non-null object
# sex                30676 non-null object
# hindfoot_length    30676 non-null float64
# weight             30676 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.3+ MB

# %%
(p9.ggplot(data=surveys_complete))
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# <ggplot: (273492509)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length')))
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# <ggplot: (-9223372036581283093)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
+p9.geom_point()
)
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (272707413)>

# %%
surveys_plot = (p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length')))
surveys_plot + p9.geom_point()
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (306364487)>

# %%
surveys_plot + p9.geom_point(alpha=0.1)
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (306364494)>

# %%
surveys_plot + p9.geom_point(alpha=0.1,color='blue')
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (307931105)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
+p9.geom_point(alpha=0.1)
)
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (309445503)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
+p9.geom_point(alpha=0.1)
+p9.xlab("Weight (g)")
)
# Out:
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/scales/scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# /Users/teaching/miniconda3/lib/python3.7/site-packages/plotnine/utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (-9223372036545327458)>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
+p9.geom_point(alpha=0.1)
+p9.xlab("Weight (g)")
 +p9.scale_x_log10()
 +p9.theme_bw()
 +p9.theme(text=p9.element_text(size=16))
)
# Out:
# <ggplot: (-9223372036546263769)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id', y='weight'))
+p9.geom_boxplot()
)
# Out:
# <ggplot: (308525064)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id', y='weight'))
+p9.geom_boxplot()
 +p9.geom_jitter(alpha=0.1)
)
# Out:
# <ggplot: (-9223372036546251965)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
+ p9.geom_point(alpha=0.1)
 +p9.facet_wrap('sex')
)
# Out:
# <ggplot: (312926314)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
+ p9.geom_point(alpha=0.1)
 +p9.facet_wrap('plot_id')
)
# Out:
# <ggplot: (309466004)>
