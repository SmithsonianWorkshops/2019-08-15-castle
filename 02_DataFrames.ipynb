# %%
import pandas as pd

# %%
pd.read_csv('data/surveys.csv')
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# 11            12      7   16  1977        7         DM    M             38.0
# 12            13      7   16  1977        3         DM    M             35.0
# 13            14      7   16  1977        8         DM  NaN              NaN
# 14            15      7   16  1977        6         DM    F             36.0
# 15            16      7   16  1977        4         DM    F             36.0
# 16            17      7   16  1977        3         DS    F             48.0
# 17            18      7   16  1977        2         PP    M             22.0
# 18            19      7   16  1977        4         PF  NaN              NaN
# 19            20      7   17  1977       11         DS    F             48.0
# 20            21      7   17  1977       14         DM    F             34.0
# 21            22      7   17  1977       15         NL    F             31.0
# 22            23      7   17  1977       13         DM    M             36.0
# 23            24      7   17  1977       13         SH    M             21.0
# 24            25      7   17  1977        9         DM    M             35.0
# 25            26      7   17  1977       15         DM    M             31.0
# 26            27      7   17  1977       15         DM    M             36.0
# 27            28      7   17  1977       11         DM    M             38.0
# 28            29      7   17  1977       11         PP    M              NaN
# 29            30      7   17  1977       10         DS    F             52.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35519      35520     12   31  2002        9         SF  NaN             24.0
# 35520      35521     12   31  2002        9         DM    M             37.0
# 35521      35522     12   31  2002        9         DM    F             35.0
# 35522      35523     12   31  2002        9         DM    F             36.0
# 35523      35524     12   31  2002        9         PB    F             25.0
# 35524      35525     12   31  2002        9         OL    M             21.0
# 35525      35526     12   31  2002        8         OT    F             20.0
# 35526      35527     12   31  2002       13         DO    F             33.0
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35528      35529     12   31  2002       13         PB    F             25.0
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 35519    36.0
# 35520    48.0
# 35521    45.0
# 35522    44.0
# 35523    27.0
# 35524    26.0
# 35525    24.0
# 35526    43.0
# 35527     NaN
# 35528    25.0
# 35529     NaN
# 35530     NaN
# 35531    43.0
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
# 35537    31.0
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
 surveys_df = pd.read_csv('data/surveys.csv')

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# 11            12      7   16  1977        7         DM    M             38.0
# 12            13      7   16  1977        3         DM    M             35.0
# 13            14      7   16  1977        8         DM  NaN              NaN
# 14            15      7   16  1977        6         DM    F             36.0
# 15            16      7   16  1977        4         DM    F             36.0
# 16            17      7   16  1977        3         DS    F             48.0
# 17            18      7   16  1977        2         PP    M             22.0
# 18            19      7   16  1977        4         PF  NaN              NaN
# 19            20      7   17  1977       11         DS    F             48.0
# 20            21      7   17  1977       14         DM    F             34.0
# 21            22      7   17  1977       15         NL    F             31.0
# 22            23      7   17  1977       13         DM    M             36.0
# 23            24      7   17  1977       13         SH    M             21.0
# 24            25      7   17  1977        9         DM    M             35.0
# 25            26      7   17  1977       15         DM    M             31.0
# 26            27      7   17  1977       15         DM    M             36.0
# 27            28      7   17  1977       11         DM    M             38.0
# 28            29      7   17  1977       11         PP    M              NaN
# 29            30      7   17  1977       10         DS    F             52.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35519      35520     12   31  2002        9         SF  NaN             24.0
# 35520      35521     12   31  2002        9         DM    M             37.0
# 35521      35522     12   31  2002        9         DM    F             35.0
# 35522      35523     12   31  2002        9         DM    F             36.0
# 35523      35524     12   31  2002        9         PB    F             25.0
# 35524      35525     12   31  2002        9         OL    M             21.0
# 35525      35526     12   31  2002        8         OT    F             20.0
# 35526      35527     12   31  2002       13         DO    F             33.0
# 35527      35528     12   31  2002       13         US  NaN              NaN
# 35528      35529     12   31  2002       13         PB    F             25.0
# 35529      35530     12   31  2002       13         OT    F             20.0
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35531      35532     12   31  2002       14         DM    F             34.0
# 35532      35533     12   31  2002       14         DM    F             36.0
# 35533      35534     12   31  2002       14         DM    M             37.0
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# ...       ...
# 35519    36.0
# 35520    48.0
# 35521    45.0
# 35522    44.0
# 35523    27.0
# 35524    26.0
# 35525    24.0
# 35526    43.0
# 35527     NaN
# 35528    25.0
# 35529     NaN
# 35530     NaN
# 35531    43.0
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
# 35537    31.0
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.head(10)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
len(pd.unique(surveys_df['species_id']))
# Out:
# 49

# %%
site_names = pd.unique(surveys_df['plot_id'])
len(site_names)
# Out:
# 24

# %%
surveys_df['plot_id'].nunique()
# Out:
# 24

# %%
surveys_df['species_id'].nunique()
# Out:
# 48

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].mean()
# Out:
# 42.672428212991356

# %%
grouped_data = surveys_df.groupby('sex')

# %%
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.587253  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.396184  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
grouped_data['weight'].describe()
# Out:
#        count       mean        std  min   25%   50%   75%    max
# sex
# F    15303.0  42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    16879.0  42.995379  36.184981  4.0  20.0  39.0  49.0  280.0

# %%
grouped_data2 = surveys_df.groupby(['species_id', 'sex'])

# %%
grouped_data2.mean()
# Out:
#                    record_id      month        day         year    plot_id  \
# species_id sex
# AH         M    22330.000000   6.000000   8.000000  1995.000000  16.000000
# BA         F    18658.451613   6.387097  13.419355  1990.870968  10.903226
#            M    18385.857143   8.214286  11.642857  1990.500000  10.214286
# DM         F    15448.699605   6.405797  16.248353  1988.787879  11.047431
#            M    16071.827944   6.291004  16.094153  1989.285642  10.785726
# DO         F    17035.387615   6.072630  15.521407  1989.943425   8.229358
#            M    18670.820738   6.141183  15.896309  1991.135911   8.218512
# DS         F     6015.080808   6.536195  15.235690  1981.818182  10.867845
#            M     6151.857480   6.210236  15.746457  1982.003150  10.414173
# NL         F    14693.844444   6.863704  16.647407  1988.099259  12.632593
#            M    13648.402390   6.962151  17.053785  1987.370518  10.958167
# OL         F    10934.692632   6.284211  15.934737  1985.503158   9.816842
#            M    11484.576172   6.623047  15.773438  1985.849609  10.066406
# OT         F    20190.142857   7.228950  16.266793  1992.170293  11.168401
#            M    20035.259516   7.239619  16.121972  1992.029412  10.815744
# OX         F      137.250000   8.500000  15.500000  1977.000000  10.250000
#            M     6492.200000   7.800000  14.600000  1981.800000  13.600000
# PB         F    31631.981166   7.376671  15.363305  2000.264277  13.230863
#            M    31143.734375   7.209704  15.953125  1999.990132  12.310033
# PE         F    16256.756477   6.407599  15.552677  1989.284974  13.025907
#            M    15652.796562   6.349570  16.320917  1988.846705  13.047278
# PF         F    18019.494055   6.924703  16.523118  1990.985469  13.367239
#            M    16950.351716   6.243873  17.191176  1990.227941  12.926471
# PH         F    16552.571429   6.380952  17.809524  1989.428571  16.666667
#            M    15123.545455   7.454545  13.545455  1988.454545  14.454545
# PI         M    32480.875000   7.375000  15.625000  2000.875000   7.125000
# PL         F    25629.000000   5.937500  17.937500  1996.750000  15.125000
#            M    26521.157895   6.105263  18.736842  1997.210526  14.526316
# PM         F    20084.845550   6.164921  17.303665  1992.321990  14.238220
#            M    18880.964072   6.491018  18.163673  1991.365269  13.928144
# PP         F    24701.294776   7.028607  16.110697  1995.613806  10.120647
#            M    25984.515668   6.723433  15.966621  1996.545640  10.337875
# PX         F    24991.000000   2.000000   8.000000  1997.000000  23.000000
#            M    25137.000000   2.000000   9.000000  1997.000000  13.000000
# RF         F    16234.736842   5.333333  11.087719  1989.175439  13.684211
#            M    14791.222222   5.166667  10.555556  1988.166667   9.833333
# RM         F    16235.573812   5.735613  14.974145  1989.367807  13.478732
#            M    16628.435137   5.340252  15.217939  1989.716086  13.943662
# RO         F    30831.250000   8.250000  20.250000  1999.250000  11.250000
#            M    34222.500000   5.750000  15.250000  2002.000000  12.000000
# RX         M    23703.500000   3.000000  19.500000  1996.000000   7.000000
# SF         F    19949.117647   6.647059  15.705882  1991.705882  14.588235
#            M    20942.913043   5.739130  17.913043  1992.478261  15.869565
# SH         F    17526.833333   5.717949  12.512821  1990.141026  11.525641
#            M    21446.738462   6.338462  12.323077  1992.938462  10.753846
# SO         F    20524.531250   6.812500  11.781250  1992.406250   7.125000
#            M    20263.000000   6.363636  15.909091  1992.272727   8.545455
# SS         F     4875.000000  10.000000  24.000000  1981.000000  20.000000
#            M    10465.000000   5.000000   7.000000  1985.000000  11.500000
#
#                 hindfoot_length      weight
# species_id sex
# AH         M                NaN         NaN
# BA         F          13.161290    9.161290
#            M          12.642857    7.357143
# DM         F          35.712692   41.609685
#            M          36.188229   44.353134
# DO         F          35.486334   48.531250
#            M          35.698780   49.135102
# DS         F          49.583174  117.749548
#            M          50.301939  122.290984
# NL         F          32.024194  154.282209
#            M          32.577434  165.652893
# OL         F          20.287671   31.065817
#            M          20.758333   32.068410
# OT         F          20.281649   24.830904
#            M          20.257399   23.695382
# OX         F          19.666667   21.000000
#            M          18.800000   21.000000
# PB         F          25.882675   30.210884
#            M          26.431987   33.816498
# PE         F          20.272059   22.822183
#            M          20.132132   20.584906
# PF         F          15.550624    7.974394
#            M          15.620779    7.885287
# PH         F          25.900000   30.850000
#            M          25.545455   31.454545
# PI         M          22.500000   19.428571
# PL         F          19.750000   19.312500
#            M          20.263158   18.684211
# PM         F          20.279778   22.125668
#            M          20.530021   20.801205
# PP         F          21.676620   17.180670
#            M          21.838643   17.184486
# PX         F          19.000000   20.000000
#            M          20.000000   18.000000
# RF         F          17.527273   13.684211
#            M          17.500000   12.444444
# RM         F          16.391880   11.102196
#            M          16.491512   10.123226
# RO         F          14.750000   11.000000
#            M          16.000000    9.500000
# RX         M          18.500000   15.500000
# SF         F          27.500000   69.000000
#            M          26.347826   53.434783
# SH         F          29.028169   78.756410
#            M          27.983333   65.177419
# SO         F          25.633333   55.322581
#            M          25.727273   55.700000
# SS         F                NaN   57.000000
#            M                NaN  130.000000

# %%
grouped_data2['weight'].mean()
# Out:
# species_id  sex
# AH          M             NaN
# BA          F        9.161290
#             M        7.357143
# DM          F       41.609685
#             M       44.353134
# DO          F       48.531250
#             M       49.135102
# DS          F      117.749548
#             M      122.290984
# NL          F      154.282209
#             M      165.652893
# OL          F       31.065817
#             M       32.068410
# OT          F       24.830904
#             M       23.695382
# OX          F       21.000000
#             M       21.000000
# PB          F       30.210884
#             M       33.816498
# PE          F       22.822183
#             M       20.584906
# PF          F        7.974394
#             M        7.885287
# PH          F       30.850000
#             M       31.454545
# PI          M       19.428571
# PL          F       19.312500
#             M       18.684211
# PM          F       22.125668
#             M       20.801205
# PP          F       17.180670
#             M       17.184486
# PX          F       20.000000
#             M       18.000000
# RF          F       13.684211
#             M       12.444444
# RM          F       11.102196
#             M       10.123226
# RO          F       11.000000
#             M        9.500000
# RX          M       15.500000
# SF          F       69.000000
#             M       53.434783
# SH          F       78.756410
#             M       65.177419
# SO          F       55.322581
#             M       55.700000
# SS          F       57.000000
#             M      130.000000
# Name: weight, dtype: float64

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
# %matplotlib inline

# %%
species_counts.plot(kind = 'bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
total_count.plot(kind='bar')

# %%
surveys_df['weight']*2.2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#          ...
# 35519     79.2
# 35520    105.6
# 35521     99.0
# 35522     96.8
# 35523     59.4
# 35524     57.2
# 35525     52.8
# 35526     94.6
# 35527      NaN
# 35528     55.0
# 35529      NaN
# 35530      NaN
# 35531     94.6
# 35532    105.6
# 35533    123.2
# 35534    116.6
# 35535     92.4
# 35536    101.2
# 35537     68.2
# 35538    149.6
# 35539     50.6
# 35540     68.2
# 35541     63.8
# 35542     74.8
# 35543      NaN
# 35544      NaN
# 35545      NaN
# 35546     30.8
# 35547    112.2
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64
